# %%
import pandas as pd

import numpy as np


pd.set_option('display.max_columns', None)

# %%
df= pd.read_csv("employee_attrition.csv")

# %%
df
# Out:
#       EmployeeID  Age      Gender MaritalStatus          Education  \
# 0      EMP000001   39        Male        Single  Bachelor's Degree
# 1      EMP000002   37        male      Divorced  Bachelor's Degree
# 2      EMP000003   54        Male      Divorced    Master's Degree
# 3      EMP000004   58      Female       Married  Bachelor's Degree
# 4      EMP000005   32        Male        Single                PhD
# ...          ...  ...         ...           ...                ...
# 49995  EMP049996   26        Male        Single                NaN
# 49996  EMP049997   57      Female      Divorced                PhD
# 49997  EMP049998   32  Non-Binary      Divorced  Bachelor's Degree
# 49998  EMP049999   46        Male      Divorced                PhD
# 49999  EMP050000   27      Female       Married  Bachelor's Degree
#
#          EducationField   Region   Department               JobRole  \
# 0                 Other  Central  Engineering     Software Engineer
# ...

# %%
df.shape
# Out:
# (50000, 43)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                50000 non-null  str
#  1   Age                       50000 non-null  int64
#  2   Gender                    50000 non-null  str
#  3   MaritalStatus             50000 non-null  str
#  4   Education                 49742 non-null  str
#  5   EducationField            50000 non-null  str
#  6   Region                    50000 non-null  str
#  7   Department                50000 non-null  str
#  8   JobRole                   50000 non-null  str
#  9   EmploymentType            50000 non-null  str
#  10  ShiftType                 50000 non-null  str
#  11  BusinessTravel            50000 non-null  str
#  12  CompanySize               50000 non-null  str
#  13  HireDate                  50000 non-null  str
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'MaritalStatus', 'Education',
#        'EducationField', 'Region', 'Department', 'JobRole', 'EmploymentType',
#        'ShiftType', 'BusinessTravel', 'CompanySize', 'HireDate',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'TotalWorkingYears', 'NumCompaniesBefore', 'MonthlyIncome',
#        'HourlyRate', 'DailyRate', 'PercentSalaryHike', 'StockOptionLevel',
#        'PerformanceRating', 'LastPerformanceScore', 'JobSatisfaction',
#        'EnvironmentSatisfaction', 'RelationshipSatisfaction', 'ManagerRating',
#        'WorkLifeBalance', 'OverTime', 'DistanceFromHome_km',
#        'RemoteWorkPercent', 'NumProjectsHandled', 'TrainingTimesLastYear',
#        'TeamSize', 'NumDirectReports', 'AbsenteeismDays', 'GrievancesFiled',
#        'AwardsWon', 'Attrition', 'ExitReason'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# EmployeeID                      0
# Age                             0
# Gender                          0
# MaritalStatus                   0
# Education                     258
# EducationField                  0
# Region                          0
# Department                      0
# JobRole                         0
# EmploymentType                  0
# ShiftType                       0
# BusinessTravel                  0
# CompanySize                     0
# HireDate                        0
# YearsAtCompany                  0
# YearsInCurrentRole              0
# YearsSinceLastPromotion         0
# TotalWorkingYears               0
# NumCompaniesBefore              0
# MonthlyIncome                2080
# HourlyRate                      0
# DailyRate                       0
# PercentSalaryHike            1167
# StockOptionLevel                0
# PerformanceRating               0
# LastPerformanceScore          496
# JobSatisfaction              1498
# ...

# %%
df.sample(5)
# Out:
#       EmployeeID  Age      Gender MaritalStatus          Education  \
# 1996   EMP001997   33        Male      Divorced  Bachelor's Degree
# 32644  EMP032645   44        Male      Divorced    Master's Degree
# 27785  EMP027786   32      Female       Married        High School
# 17797  EMP017798   40      Female       Married  Bachelor's Degree
# 46394  EMP046395   51  Non-Binary      Divorced  Bachelor's Degree
#
#       EducationField Region        Department              JobRole  \
# 1996           Other   West       Engineering  Engineering Manager
# 32644      Marketing  South  Customer Support        Support Agent
# 27785      Marketing  North                IT           IT Support
# 17797      Marketing   East        Operations   Operations Analyst
# 46394        Medical  South        Operations                  COO
#
#       EmploymentType ShiftType BusinessTravel CompanySize    HireDate  \
# 1996       Full-Time       Day      No Travel      Medium  2023-03-28
# ...

# %%
df['Department'].unique()
# Out:
# <StringArray>
# [         'Engineering',                   'HR',                  'R&D',
#             'Marketing',              'Finance',                'Legal',
#                    'IT',     'Customer Support',           'Operations',
#                 'Sales',          'ENGINEERING',      '  Engineering  ',
#        '  Operations  ',               '  IT  ',              'FINANCE',
#      'CUSTOMER SUPPORT',            '  Legal  ',                'SALES',
#            'OPERATIONS',              '  R&D  ',                'LEGAL',
#       '  ENGINEERING  ',        '  Marketing  ',            'MARKETING',
#             '  Sales  ', '  Customer Support  ',               '  HR  ',
#           '  Finance  ',            '  SALES  ']
# Length: 29, dtype: str

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'male', 'Female', 'Non-Binary', 'non-binary', 'female']
# Length: 6, dtype: str

# %%
df.describe()
# Out:
#                 Age  YearsAtCompany  YearsInCurrentRole  \
# count  50000.000000    50000.000000        50000.000000
# mean      43.957000        8.018822            3.741414
# std       46.508586        4.610181            2.741097
# min       -5.000000        0.000000            0.000000
# 25%       32.000000        4.000000            1.400000
# 50%       42.000000        8.000000            3.100000
# 75%       52.000000       12.000000            5.700000
# max      999.000000       16.000000           20.300000
#
#        YearsSinceLastPromotion  TotalWorkingYears  NumCompaniesBefore  \
# count             50000.000000       50000.000000        50000.000000
# mean                  1.847638          13.928912            4.010000
# std                   1.867793           5.850793            2.583415
# min                   0.000000           0.000000            0.000000
# 25%                   0.500000           9.700000            2.000000
# ...

# %%
print(df['Age'].duplicated().sum())
# Out:
# 49954

# %%
df[df['Attrition'] == 'No']['ExitReason'].isnull().sum()
# Out:
# np.int64(31877)

# %%
df['HireDate']= pd.to_datetime(df['HireDate'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                50000 non-null  str
#  1   Age                       50000 non-null  int64
#  2   Gender                    50000 non-null  str
#  3   MaritalStatus             50000 non-null  str
#  4   Education                 49742 non-null  str
#  5   EducationField            50000 non-null  str
#  6   Region                    50000 non-null  str
#  7   Department                50000 non-null  str
#  8   JobRole                   50000 non-null  str
#  9   EmploymentType            50000 non-null  str
#  10  ShiftType                 50000 non-null  str
#  11  BusinessTravel            50000 non-null  str
#  12  CompanySize               50000 non-null  str
#  13  HireDate                  50000 non-null  datetime64[us]
# ...

# %%
df['HireYear'] = df['HireDate'].dt.year
df['HireMonth'] = df['HireDate'].dt.month

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                50000 non-null  str
#  1   Age                       50000 non-null  int64
#  2   Gender                    50000 non-null  str
#  3   MaritalStatus             50000 non-null  str
#  4   Education                 49742 non-null  str
#  5   EducationField            50000 non-null  str
#  6   Region                    50000 non-null  str
#  7   Department                50000 non-null  str
#  8   JobRole                   50000 non-null  str
#  9   EmploymentType            50000 non-null  str
#  10  ShiftType                 50000 non-null  str
#  11  BusinessTravel            50000 non-null  str
#  12  CompanySize               50000 non-null  str
#  13  HireDate                  50000 non-null  datetime64[us]
# ...

# %%
df['Tenure'] = 2026 - df['HireDate'].dt.year

# %%
df['Tenure'].describe()
# Out:
# count    50000.000000
# mean        10.517040
# std          4.600258
# min          3.000000
# 25%          7.000000
# 50%         11.000000
# 75%         15.000000
# max         18.000000
# Name: Tenure, dtype: float64

# %%
df.groupby('Attrition')['Tenure'].mean()
# Out:
# Attrition
# 0        10.903614
# 1        10.400000
# FALSE    10.331126
# No       10.466167
# TRUE     10.544304
# Yes      10.614006
# no       10.363636
# yes      10.560440
# Name: Tenure, dtype: float64

# %%
df['Attrition'] = df['Attrition'].astype(str).str.strip().str.lower()

# %%
df['Attrition'].unique()
# Out:
# <StringArray>
# ['no', 'yes', 'false', 'true', '0', '1']
# Length: 6, dtype: str

# %%
df['Attrition'] = df['Attrition'].str.strip().str.lower()

df['Attrition'] = df['Attrition'].replace({
    'yes': 'Yes',
    'no': 'No',
    'true': 'Yes',
    'false': 'No',
    '1': 'Yes',
    '0': 'No'
})

# %%
df['Attrition'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df.groupby('Attrition')['Tenure'].mean()
# Out:
# Attrition
# No     10.466663
# Yes    10.610977
# Name: Tenure, dtype: float64

# %%
df.groupby('OverTime')['Attrition'].value_counts(normalize=True)
# Out:
# OverTime  Attrition
# No        No           0.685529
#           Yes          0.314471
# Yes       No           0.585947
#           Yes          0.414053
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                50000 non-null  str
#  1   Age                       50000 non-null  int64
#  2   Gender                    50000 non-null  str
#  3   MaritalStatus             50000 non-null  str
#  4   Education                 49742 non-null  str
#  5   EducationField            50000 non-null  str
#  6   Region                    50000 non-null  str
#  7   Department                50000 non-null  str
#  8   JobRole                   50000 non-null  str
#  9   EmploymentType            50000 non-null  str
#  10  ShiftType                 50000 non-null  str
#  11  BusinessTravel            50000 non-null  str
#  12  CompanySize               50000 non-null  str
#  13  HireDate                  50000 non-null  datetime64[us]
# ...

# %%
df['Education'] = df['Education'].fillna(df['Education'].mode()[0])

df['MonthlyIncome'] = df['MonthlyIncome'].fillna(df['MonthlyIncome'].median())

# %%
df.isnull().sum()
# Out:
# EmployeeID                      0
# Age                             0
# Gender                          0
# MaritalStatus                   0
# Education                       0
# EducationField                  0
# Region                          0
# Department                      0
# JobRole                         0
# EmploymentType                  0
# ShiftType                       0
# BusinessTravel                  0
# CompanySize                     0
# HireDate                        0
# YearsAtCompany                  0
# YearsInCurrentRole              0
# YearsSinceLastPromotion         0
# TotalWorkingYears               0
# NumCompaniesBefore              0
# MonthlyIncome                   0
# HourlyRate                      0
# DailyRate                       0
# PercentSalaryHike            1167
# StockOptionLevel                0
# PerformanceRating               0
# LastPerformanceScore          496
# JobSatisfaction              1498
# ...

# %%
df['PercentSalaryHike'] = df['PercentSalaryHike'].fillna(df['PercentSalaryHike'].median())

# %%
df.loc[df['Attrition'] == 'No', 'ExitReason'] = 'Not Applicable'

# %%
df.loc[(df['Attrition'] == 'Yes') & (df['ExitReason'].isnull()), 'ExitReason'] = 'Unknown'

# %%
df.isnull().sum()
# Out:
# EmployeeID                     0
# Age                            0
# Gender                         0
# MaritalStatus                  0
# Education                      0
# EducationField                 0
# Region                         0
# Department                     0
# JobRole                        0
# EmploymentType                 0
# ShiftType                      0
# BusinessTravel                 0
# CompanySize                    0
# HireDate                       0
# YearsAtCompany                 0
# YearsInCurrentRole             0
# YearsSinceLastPromotion        0
# TotalWorkingYears              0
# NumCompaniesBefore             0
# MonthlyIncome                  0
# HourlyRate                     0
# DailyRate                      0
# PercentSalaryHike              0
# StockOptionLevel               0
# PerformanceRating              0
# LastPerformanceScore         496
# JobSatisfaction             1498
# EnvironmentSatisfaction      750
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age                    HireDate  YearsAtCompany  \
# count  50000.000000                       50000    50000.000000
# mean      43.957000  2015-12-25 03:38:32.064000        8.018822
# min       -5.000000         2008-01-01 00:00:00        0.000000
# 25%       32.000000         2011-12-30 00:00:00        4.000000
# 50%       42.000000         2015-12-19 00:00:00        8.000000
# 75%       52.000000         2019-12-19 00:00:00       12.000000
# max      999.000000         2023-12-31 00:00:00       16.000000
# std       46.508586                         NaN        4.610181
#
#        YearsInCurrentRole  YearsSinceLastPromotion  TotalWorkingYears  \
# count        50000.000000             50000.000000       50000.000000
# mean             3.741414                 1.847638          13.928912
# min              0.000000                 0.000000           0.000000
# 25%              1.400000                 0.500000           9.700000
# ...

# %%
df = df[(df['Age'] >= 18) & (df['Age'] <= 65)]

# %%
df = df[(df['MonthlyIncome'] > 1000) & (df['MonthlyIncome'] < 100000)]

# %%
df['NumProjectsHandled']
# Out:
# 0         2
# 1        10
# 2         3
# 3         9
# 4         2
#          ..
# 49995     6
# 49996     5
# 49997     4
# 49998     9
# 49999     3
# Name: NumProjectsHandled, Length: 49031, dtype: int64

# %%
df = df[df['NumProjectsHandled'] >= 0]
df = df[df['TrainingTimesLastYear'] >= 0]

# %%
cols_to_fill = [
    'JobSatisfaction',
    'EnvironmentSatisfaction',
    'RelationshipSatisfaction',
    'ManagerRating',
    'AbsenteeismDays'
]

for col in cols_to_fill:
    df[col] = df[col].fillna(df[col].median())

# %%
df.describe()
# Out:
#                 Age                    HireDate  YearsAtCompany  \
# count  48051.000000                       48051    48051.000000
# mean      41.960396  2015-12-24 14:28:03.461322        8.020335
# min       22.000000         2008-01-01 00:00:00        0.000000
# 25%       32.000000         2012-01-02 00:00:00        4.000000
# 50%       42.000000         2015-12-16 00:00:00        8.000000
# 75%       52.000000         2019-12-16 00:00:00       12.000000
# max       62.000000         2023-12-31 00:00:00       16.000000
# std       11.837960                         NaN        4.605870
#
#        YearsInCurrentRole  YearsSinceLastPromotion  TotalWorkingYears  \
# count        48051.000000             48051.000000       48051.000000
# mean             3.745849                 1.850561          13.930449
# min              0.000000                 0.000000           0.000000
# 25%              1.400000                 0.500000           9.700000
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID                    0
# Age                           0
# Gender                        0
# MaritalStatus                 0
# Education                     0
# EducationField                0
# Region                        0
# Department                    0
# JobRole                       0
# EmploymentType                0
# ShiftType                     0
# BusinessTravel                0
# CompanySize                   0
# HireDate                      0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# TotalWorkingYears             0
# NumCompaniesBefore            0
# MonthlyIncome                 0
# HourlyRate                    0
# DailyRate                     0
# PercentSalaryHike             0
# StockOptionLevel              0
# PerformanceRating             0
# LastPerformanceScore        479
# JobSatisfaction               0
# EnvironmentSatisfaction       0
# RelationshipSatisfaction      0
# ...

# %%
df.groupby(['OverTime', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# OverTime  Attrition
# No        No           9061.790552
#           Yes          9077.062564
# Yes       No           9068.565759
#           Yes          9052.152704
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('JobSatisfaction')['Attrition'].value_counts(normalize=True)
# Out:
# JobSatisfaction  Attrition
# 1.0              No           0.577016
#                  Yes          0.422984
# 2.0              No           0.580860
#                  Yes          0.419140
# 3.0              No           0.703131
#                  Yes          0.296869
# 4.0              No           0.697248
#                  Yes          0.302752
# 5.0              No           0.691023
#                  Yes          0.308977
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby('JobSatisfaction')['Attrition'].value_counts(normalize=True).unstack().plot(kind='bar')

plt.title("Attrition by Job Satisfaction")
plt.xlabel("Job Satisfaction")
plt.ylabel("Proportion")

plt.show()

# %%
df.groupby(['OverTime', 'JobSatisfaction'])['Attrition'].value_counts(normalize=True)
# Out:
# OverTime  JobSatisfaction  Attrition
# No        1.0              No           0.614713
#                            Yes          0.385287
#           2.0              No           0.621635
#                            Yes          0.378365
#           3.0              No           0.733458
#                            Yes          0.266542
#           4.0              No           0.730574
#                            Yes          0.269426
#           5.0              No           0.723806
#                            Yes          0.276194
# Yes       1.0              No           0.506364
#                            Yes          0.493636
#           2.0              No           0.506094
#                            Yes          0.493906
#           3.0              No           0.646042
#                            Yes          0.353958
#           4.0              No           0.634775
#                            Yes          0.365225
# ...

# %%
df.groupby('Department')['Attrition'].value_counts(normalize=True)
# Out:
# Department            Attrition
#   Customer Support    No           0.600000
#                       Yes          0.400000
#   ENGINEERING         No           0.500000
#                       Yes          0.500000
#   Engineering         No           0.757576
#                       Yes          0.242424
#   Finance             No           0.608696
#                       Yes          0.391304
#   HR                  No           0.575000
#                       Yes          0.425000
#   IT                  No           0.514286
#                       Yes          0.485714
#   Legal               No           0.666667
#                       Yes          0.333333
#   Marketing           No           0.615385
#                       Yes          0.384615
#   Operations          No           0.660000
#                       Yes          0.340000
#   R&D                 No           0.651163
#                       Yes          0.348837
#   SALES               No           1.000000
# ...

# %%
df['Department'] = df['Department'].str.strip().str.title()

# %%
df['Department'].unique()
# Out:
# <StringArray>
# [     'Engineering',               'Hr',              'R&D',
#         'Marketing',          'Finance',            'Legal',
#                'It', 'Customer Support',       'Operations',
#             'Sales']
# Length: 10, dtype: str

# %%
df.groupby('Department')['Attrition'].value_counts(normalize=True)
# Out:
# Department        Attrition
# Customer Support  No           0.649534
#                   Yes          0.350466
# Engineering       No           0.652795
#                   Yes          0.347205
# Finance           No           0.648229
#                   Yes          0.351771
# Hr                No           0.647264
#                   Yes          0.352736
# It                No           0.656572
#                   Yes          0.343428
# Legal             No           0.649691
#                   Yes          0.350309
# Marketing         No           0.646646
#                   Yes          0.353354
# Operations        No           0.656257
#                   Yes          0.343743
# R&D               No           0.650348
#                   Yes          0.349652
# Sales             No           0.653774
#                   Yes          0.346226
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby('Department')['Attrition'].value_counts(normalize=True).unstack().plot(kind='bar')

plt.title("Attrition by Department")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 48051 entries, 0 to 49999
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                48051 non-null  str
#  1   Age                       48051 non-null  int64
#  2   Gender                    48051 non-null  str
#  3   MaritalStatus             48051 non-null  str
#  4   Education                 48051 non-null  str
#  5   EducationField            48051 non-null  str
#  6   Region                    48051 non-null  str
#  7   Department                48051 non-null  str
#  8   JobRole                   48051 non-null  str
#  9   EmploymentType            48051 non-null  str
#  10  ShiftType                 48051 non-null  str
#  11  BusinessTravel            48051 non-null  str
#  12  CompanySize               48051 non-null  str
#  13  HireDate                  48051 non-null  datetime64[us]
# ...

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    df[col] = df[col].str.strip().str.title()
# Out:
# C:\Users\ROHIT DEY\AppData\Local\Temp\ipykernel_26108\2218623814.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include='object').columns

# %%
cat_cols = df.select_dtypes(include=['object', 'string']).columns

for col in cat_cols:
    df[col] = df[col].str.strip().str.title()

# %%
df['Department'].value_counts()
# Out:
# Department
# Engineering         4902
# Hr                  4879
# Marketing           4845
# Finance             4827
# Customer Support    4825
# Operations          4803
# Sales               4783
# It                  4755
# R&D                 4739
# Legal               4693
# Name: count, dtype: int64

# %%
df['Department'] = df['Department'].replace({
    'Hr': 'HR',
    'It': 'IT'
})

# %%
df.groupby('Department')['Attrition'].value_counts(normalize=True)
# Out:
# Department        Attrition
# Customer Support  No           0.649534
#                   Yes          0.350466
# Engineering       No           0.652795
#                   Yes          0.347205
# Finance           No           0.648229
#                   Yes          0.351771
# HR                No           0.647264
#                   Yes          0.352736
# IT                No           0.656572
#                   Yes          0.343428
# Legal             No           0.649691
#                   Yes          0.350309
# Marketing         No           0.646646
#                   Yes          0.353354
# Operations        No           0.656257
#                   Yes          0.343743
# R&D               No           0.650348
#                   Yes          0.349652
# Sales             No           0.653774
#                   Yes          0.346226
# Name: proportion, dtype: float64

# %%
df.groupby('Department')['Attrition'].value_counts(normalize=True)
# Out:
# Department        Attrition
# Customer Support  No           0.649534
#                   Yes          0.350466
# Engineering       No           0.652795
#                   Yes          0.347205
# Finance           No           0.648229
#                   Yes          0.351771
# HR                No           0.647264
#                   Yes          0.352736
# IT                No           0.656572
#                   Yes          0.343428
# Legal             No           0.649691
#                   Yes          0.350309
# Marketing         No           0.646646
#                   Yes          0.353354
# Operations        No           0.656257
#                   Yes          0.343743
# R&D               No           0.650348
#                   Yes          0.349652
# Sales             No           0.653774
#                   Yes          0.346226
# Name: proportion, dtype: float64

# %%
print(f"Loaded: {df.shape[0]:,} rows × {df.shape[1]} columns\n")
# Out:
# Loaded: 48,051 rows × 46 columns

# %%
print("Before:", df['Education'].value_counts.to_dict())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 print("Before:", df['Education'].value_counts.to_dict())
#
# AttributeError: 'function' object has no attribute 'to_dict'

# %%
edu_fix = {
    "Bachelor'S Degree" : "Bachelor's Degree",
    "Master'S Degree"   : "Master's Degree",
    "Phd"               : "PhD",
}
df['Education'] = df['Education'].replace(edu_fix)

# %%
print("After :", df['Education'].value_counts().to_dict())
# Out:
# After : {"Bachelor's Degree": 21815, "Master's Degree": 14259, 'Associate Degree': 4798, 'PhD': 4790, 'High School': 2389}

# %%
print("Before (sample):", [r for r in df['JobRole'].unique() if any(x in r for x in ['Hr ','It ','Cfo','Cmo','Coo','Devops','Qa ','Seo'])])
# Out:
# Before (sample): ['Seo Specialist', 'Hr Analyst', 'Hr Manager', 'Hr Director', 'Qa Specialist', 'Cmo', 'Cfo', 'Devops Engineer', 'Coo', 'It Manager', 'It Support']

# %%
print("Before:", df['JobRole'].value_counts().to_dict())
# Out:
# Before: {'Hr Analyst': 1035, 'Process Specialist': 1010, 'Software Engineer': 1001, 'Marketing Analyst': 1000, 'Lead Engineer': 998, 'Senior Analyst': 993, 'Business Development Rep': 992, 'Devops Engineer': 991, 'Hr Manager': 987, 'Sales Rep': 987, 'Support Agent': 980, 'Team Lead': 978, 'Seo Specialist': 977, 'Hr Director': 977, 'Cmo': 977, 'Senior Agent': 974, 'Cfo': 971, 'Senior Engineer': 970, 'Legal Counsel': 970, 'Sales Manager': 966, 'Network Engineer': 966, 'Finance Manager': 965, 'Senior Scientist': 965, 'It Support': 965, 'Financial Analyst': 964, 'Recruiter': 959, 'Operations Manager': 952, 'Coo': 951, 'Marketing Manager': 950, 'Research Analyst': 949, 'Legal Director': 949, 'Data Scientist': 947, 'Qa Specialist': 947, 'Support Manager': 946, 'R&D Manager': 946, 'Supply Chain Analyst': 945, 'Operations Analyst': 945, 'Legal Analyst': 944, 'Cloud Architect': 944, 'Engineering Manager': 942, 'Systems Admin': 942, 'Content Specialist': 941, 'It Manager': 938, 'Budget Analyst
# ...

# %%
jobrole_fix = {
    "Hr Analyst"    : "HR Analyst",
    "Hr Manager"    : "HR Manager",
    "Hr Director"   : "HR Director",
    "It Manager"    : "IT Manager",
    "It Support"    : "IT Support",
    "Cfo"           : "CFO",
    "Cmo"           : "CMO",
    "Coo"           : "COO",
    "Devops Engineer": "DevOps Engineer",
    "Qa Specialist" : "QA Specialist",
    "Seo Specialist": "SEO Specialist",
    "R&D Manager"   : "R&D Manager",   
}
df['JobRole'] = df['JobRole'].replace(jobrole_fix)

# %%
print("After  (sample):", [r for r in df['JobRole'].unique() if any(x in r for x in ['HR ','IT ','CFO','CMO','COO','DevOps','QA ','SEO'])])
print()
# Out:
# After  (sample): ['SEO Specialist', 'HR Analyst', 'HR Manager', 'HR Director', 'QA Specialist', 'CMO', 'CFO', 'DevOps Engineer', 'COO', 'IT Manager', 'IT Support']

# %%
print(f"Before: {len(df):,} rows | {df['EmployeeID'].duplicated().sum()} duplicate IDs")
# Out:
# Before: 48,051 rows | 485 duplicate IDs

# %%
df["EmployeeID"].duplicated().sum()
# Out:
# np.int64(485)

# %%
df = df.drop_duplicates(subset='EmployeeID', keep='first').reset_index(drop=True)

# %%
print(f"After : {len(df):,} rows | {df['EmployeeID'].duplicated().sum()} duplicate IDs\n")
# Out:
# After : 47,566 rows | 0 duplicate IDs

# %%
df['EmployeeID'].head(3).tolist()
# Out:
# ['Emp000001', 'Emp000002', 'Emp000003']

# %%
df['EmployeeID'] = df['EmployeeID'].str.replace(r'^Emp', 'EMP', regex=True)

# %%
df['EmployeeID'].head(3).tolist()
# Out:
# ['EMP000001', 'EMP000002', 'EMP000003']

# %%
print(f"Before: {df['HireDate'].dtype}")
# Out:
# Before: datetime64[us]

# %%
df['HireDate'] = pd.to_datetime(df['HireDate'], errors='coerce')

# %%
print(f"After : {df['HireDate'].dtype}\n")
# Out:
# After : datetime64[us]

# %%
print(f"Before sample (hired 2012): Tenure = {df[df['HireDate'].dt.year==2012]['Tenure'].iloc[0]} (2026−2012=14, but correct is 12)")
# Out:
# Before sample (hired 2012): Tenure = 14 (2026−2012=14, but correct is 12)

# %%
reference_date = pd.Timestamp("2024-01-01")
df['Tenure'] = ((reference_date - df['HireDate']).dt.days / 365.25).round(1)

# %%
print(f"After  sample (hired 2012): Tenure = {df[df['HireDate'].dt.year==2012]['Tenure'].iloc[0]}")
# Out:
# After  sample (hired 2012): Tenure = 11.1

# %%
print(f"Tenure range: {df['Tenure'].min()} – {df['Tenure'].max()} years\n")
# Out:
# Tenure range: 0.0 – 16.0 years

# %%
print(f"Before: {(df['YearsInCurrentRole'] > df['YearsAtCompany']).sum()} rows violate this rule")
# Out:
# Before: 1298 rows violate this rule

# %%
mask = df['YearsInCurrentRole'] > df['YearsAtCompany']
df.loc[mask, 'YearsInCurrentRole'] = df.loc[mask, 'YearsAtCompany']
print(f"After : {(df['YearsInCurrentRole'] > df['YearsAtCompany']).sum()} rows violate this rule")
# Out:
# After : 0 rows violate this rule

# %%
print(f"Before: {(df['TotalWorkingYears'] < df['YearsAtCompany']).sum()} rows violate this rule")
# Out:
# Before: 386 rows violate this rule

# %%
mask2 = df['TotalWorkingYears'] < df['YearsAtCompany']
df.loc[mask2, 'TotalWorkingYears'] = df.loc[mask2, 'YearsAtCompany']
 
print(f"After : {(df['TotalWorkingYears'] < df['YearsAtCompany']).sum()} violations remaining\n")
# Out:
# After : 0 violations remaining

# %%
print(f"Before: {(df['YearsSinceLastPromotion'] > df['YearsAtCompany']).sum()} rows violate this rule")
# Out:
# Before: 364 rows violate this rule

# %%
mask3 = df['YearsSinceLastPromotion'] > df['YearsAtCompany']
df.loc[mask3, 'YearsSinceLastPromotion'] = df.loc[mask3, 'YearsAtCompany']
 
print(f"After : {(df['YearsSinceLastPromotion'] > df['YearsAtCompany']).sum()} violations remaining\n")
# Out:
# After : 0 violations remaining

# %%
print(f"Before: LastPerformanceScore NaN = {df['LastPerformanceScore'].isna().sum()}")
print(f"Before: DistanceFromHome_km  NaN = {df['DistanceFromHome_km'].isna().sum()}")
# Out:
# Before: LastPerformanceScore NaN = 471
# Before: DistanceFromHome_km  NaN = 378

# %%
df['LastPerformanceScore'] = df['LastPerformanceScore'].fillna(df['LastPerformanceScore'].median())
df['DistanceFromHome_km']  = df['DistanceFromHome_km'].fillna(df['DistanceFromHome_km'].median())
 
print(f"After : LastPerformanceScore NaN = {df['LastPerformanceScore'].isna().sum()}")
print(f"After : DistanceFromHome_km  NaN = {df['DistanceFromHome_km'].isna().sum()}\n")
# Out:
# After : LastPerformanceScore NaN = 0
# After : DistanceFromHome_km  NaN = 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47566 entries, 0 to 47565
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                47566 non-null  str
#  1   Age                       47566 non-null  int64
#  2   Gender                    47566 non-null  str
#  3   MaritalStatus             47566 non-null  str
#  4   Education                 47566 non-null  str
#  5   EducationField            47566 non-null  str
#  6   Region                    47566 non-null  str
#  7   Department                47566 non-null  str
#  8   JobRole                   47566 non-null  str
#  9   EmploymentType            47566 non-null  str
#  10  ShiftType                 47566 non-null  str
#  11  BusinessTravel            47566 non-null  str
#  12  CompanySize               47566 non-null  str
#  13  HireDate                  47566 non-null  datetime64[us]
# ...

# %%
print("── ISSUE 11: Float → Integer dtype corrections ─────────────")
int_convert = [
    'JobSatisfaction', 'EnvironmentSatisfaction', 'ManagerRating',
    'TrainingTimesLastYear', 'AbsenteeismDays', 'DistanceFromHome_km'
]
for col in int_convert:
    print(f"  {col}: {df[col].dtype} → int64")
    df[col] = df[col].astype(int)
print()
# Out:
# ── ISSUE 11: Float → Integer dtype corrections ─────────────
#   JobSatisfaction: float64 → int64
#   EnvironmentSatisfaction: float64 → int64
#   ManagerRating: float64 → int64
#   TrainingTimesLastYear: float64 → int64
#   AbsenteeismDays: float64 → int64
#   DistanceFromHome_km: float64 → int64

# %%
inconsistent_before = ((df['HourlyRate'] - (df['MonthlyIncome']*12/2080)).abs() > 1).sum()
print(f"Before: {inconsistent_before} rows where HourlyRate doesn't match MonthlyIncome")
# Out:
# Before: 1938 rows where HourlyRate doesn't match MonthlyIncome

# %%
df['HourlyRate'] = (df['MonthlyIncome'] * 12 / 2080).round(2)
df['DailyRate']  = (df['HourlyRate'] * 8).round(2)
 
inconsistent_after = ((df['HourlyRate'] - (df['MonthlyIncome']*12/2080)).abs() > 1).sum()
print(f"After : {inconsistent_after} inconsistencies\n")
# Out:
# After : 0 inconsistencies

# %%
print("=" * 60)

# %%
print(f"\n  Final shape          : {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"  Total NaN remaining  : {df.isnull().sum().sum()}")
# Out:
#   Final shape          : 47,566 rows × 46 columns
#   Total NaN remaining  : 0

# %%
remaining = df.isnull().sum()
remaining = remaining[remaining > 0]
if len(remaining) == 0:
    print("  Missing values       : NONE ✓")
else:
    print(f"  Missing values       :\n{remaining}")
# Out:
#   Missing values       : NONE ✓

# %%
print(f"\n  Education unique     : {sorted(df['Education'].unique())}")
print(f"  Attrition unique     : {sorted(df['Attrition'].unique())}")
print(f"  Gender unique        : {sorted(df['Gender'].unique())}")
print(f"  Department unique    : {sorted(df['Department'].unique())}")
print(f"  EmployeeID format    : {df['EmployeeID'].iloc[0]} (EMP prefix ✓)")
print(f"  Duplicate IDs        : {df['EmployeeID'].duplicated().sum()}")
print(f"  HireDate dtype       : {df['HireDate'].dtype}")
print(f"  Tenure range         : {df['Tenure'].min()} – {df['Tenure'].max()} years")
# Out:
#   Education unique     : ['Associate Degree', "Bachelor's Degree", 'High School', "Master's Degree", 'PhD']
#   Attrition unique     : ['No', 'Yes']
#   Gender unique        : ['Female', 'Male', 'Non-Binary']
#   Department unique    : ['Customer Support', 'Engineering', 'Finance', 'HR', 'IT', 'Legal', 'Marketing', 'Operations', 'R&D', 'Sales']
#   EmployeeID format    : EMP000001 (EMP prefix ✓)
#   Duplicate IDs        : 0
#   HireDate dtype       : datetime64[us]
#   Tenure range         : 0.0 – 16.0 years

# %%
logic1 = (df['YearsInCurrentRole'] > df['YearsAtCompany']).sum()
logic2 = (df['TotalWorkingYears']   < df['YearsAtCompany']).sum()
logic3 = (df['YearsSinceLastPromotion'] > df['YearsAtCompany']).sum()
print(f"\n  YearsInCurrentRole > YearsAtCompany  : {logic1}")
print(f"  TotalWorkingYears < YearsAtCompany   : {logic2}")
print(f"  YearsSinceLastPromotion > YearsAtComp: {logic3}")
 
print(f"\n  JobSatisfaction dtype   : {df['JobSatisfaction'].dtype}")
print(f"  AbsenteeismDays dtype   : {df['AbsenteeismDays'].dtype}")
print(f"  DistanceFromHome dtype  : {df['DistanceFromHome_km'].dtype}")
 
print("\n  Data types overview:")
print(df.dtypes.to_string())
# Out:
#   YearsInCurrentRole > YearsAtCompany  : 0
#   TotalWorkingYears < YearsAtCompany   : 0
#   YearsSinceLastPromotion > YearsAtComp: 0
#
#   JobSatisfaction dtype   : int64
#   AbsenteeismDays dtype   : int64
#   DistanceFromHome dtype  : int64
#
#   Data types overview:
# EmployeeID                             str
# Age                                  int64
# Gender                                 str
# MaritalStatus                          str
# Education                              str
# EducationField                         str
# Region                                 str
# Department                             str
# JobRole                                str
# EmploymentType                         str
# ShiftType                              str
# BusinessTravel                         str
# CompanySize                            str
# HireDate                    datetime64[us]
# YearsAtCompany                     float64
# YearsInCurrentRole                 float64
# ...

# %%
df.to_csv("employee_attrition_final.csv", index=False)

# %%
df
# Out:
#       EmployeeID  Age      Gender MaritalStatus          Education  \
# 0      EMP000001   39        Male        Single  Bachelor's Degree
# 1      EMP000002   37        Male      Divorced  Bachelor's Degree
# 2      EMP000003   54        Male      Divorced    Master's Degree
# 3      EMP000004   58      Female       Married  Bachelor's Degree
# 4      EMP000005   32        Male        Single                PhD
# ...          ...  ...         ...           ...                ...
# 47561  EMP049996   26        Male        Single  Bachelor's Degree
# 47562  EMP049997   57      Female      Divorced                PhD
# 47563  EMP049998   32  Non-Binary      Divorced  Bachelor's Degree
# 47564  EMP049999   46        Male      Divorced                PhD
# 47565  EMP050000   27      Female       Married  Bachelor's Degree
#
#          EducationField   Region   Department               JobRole  \
# 0                 Other  Central  Engineering     Software Engineer
# ...
